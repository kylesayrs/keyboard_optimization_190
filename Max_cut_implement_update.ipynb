# %%
import cvxpy as cp
import numpy as np
import copy
from math import floor
from scipy.linalg import sqrtm
f_count = [('er', 44109),
 ('in', 40899),
 ('ar', 29110),
 ('es', 28073),
 ('or', 27803),
 ('st', 27369),
 ('an', 27011),
 ('no', 24938),
 ('it', 24248),
 ('et', 22645),
 ('en', 21483),
 ('at', 20169),
 ('al', 19878),
 ('ot', 19731),
 ('de', 19526),
 ('is', 16403),
 ('gn', 15834),
 ('rt', 15534),
 ('co', 15422),
 ('ce', 15341),
 ('il', 15004),
 ('ht', 14856),
 ('fo', 14569),
 ('el', 12934),
 ('io', 12224),
 ('eh', 11725),
 ('as', 11518),
 ('lo', 11197),
 ('ad', 10994),
 ('nt', 10774),
 ('em', 10717),
 ('ir', 10713),
 ('am', 10639),
 ('mo', 10500),
 ('ac', 10182),
 ('ae', 9926),
 ('ev', 9903),
 ('ci', 9764),
 ('ah', 9511),
 ('ou', 9223),
 ('cn', 9209),
 ('op', 8735),
 ('di', 8523),
 ('ep', 8367),
 ('su', 8286),
 ('eg', 8205),
 ('ap', 7703),
 ('ai', 7588),
 ('dn', 7529),
 ('os', 7493),
 ('pr', 7233),
 ('ew', 7205),
 ('im', 7051),
 ('gr', 7039),
 ('ch', 6953),
 ('tu', 6716),
 ('gi', 6572),
 ('ck', 6160),
 ('ru', 6144),
 ('hs', 6127),
 ('ow', 5969),
 ('nu', 5778),
 ('hi', 5680),
 ('ek', 5669),
 ('pu', 5630),
 ('iv', 5622),
 ('ct', 5603),
 ('ns', 5600),
 ('lu', 5546),
 ('ho', 5436),
 ('ly', 5251),
 ('do', 5147),
 ('ag', 4898),
 ('fi', 4844),
 ('ei', 4744),
 ('ay', 4598),
 ('rs', 4525),
 ('cr', 4453),
 ('bo', 4323),
 ('bi', 4272),
 ('nr', 4198),
 ('be', 4174),
 ('ex', 4109),
 ('ab', 3976),
 ('sy', 3889),
 ('bu', 3807),
 ('ps', 3796),
 ('dl', 3673),
 ('iw', 3667),
 ('cl', 3382),
 ('ov', 3341),
 ('pt', 3275),
 ('mu', 3199),
 ('ks', 3194),
 ('av', 3190),
 ('aw', 3080),
 ('au', 3026),
 ('ip', 2988),
 ('ef', 2940),
 ('fr', 2880),
 ('lt', 2874),
 ('gs', 2841),
 ('px', 2756),
 ('lp', 2637),
 ('cu', 2622),
 ('ey', 2583),
 ('ls', 2548),
 ('cs', 2535),
 ('go', 2528),
 ('eu', 2494),
 ('by', 2454),
 ('gh', 2404),
 ('mp', 2393),
 ('dr', 2288),
 ('kr', 2283),
 ('ty', 2281),
 ('ry', 2274),
 ('oy', 2253),
 ('af', 2230),
 ('ak', 2225),
 ('mr', 2123),
 ('qu', 2076),
 ('nv', 2039),
 ('ds', 1953),
 ('br', 1912),
 ('ik', 1854),
 ('bl', 1760),
 ('ft', 1758),
 ('du', 1689),
 ('ju', 1682),
 ('hw', 1668),
 ('ko', 1623),
 ('jo', 1610),
 ('ny', 1585),
 ('kn', 1567),
 ('iu', 1537),
 ('uy', 1456),
 ('mt', 1451),
 ('sw', 1393),
 ('gu', 1352),
 ('lr', 1347),
 ('ax', 1298),
 ('nw', 1208),
 ('ms', 1147),
 ('gy', 1117),
 ('eo', 1116),
 ('hn', 1063),
 ('py', 1052),
 ('aj', 1045),
 ('fl', 1002),
 ('hp', 985),
 ('tw', 965),
 ('az', 940),
 ('ln', 896),
 ('rv', 827),
 ('fu', 807),
 ('gt', 768),
 ('bm', 699),
 ('kl', 687),
 ('hu', 684),
 ('my', 683),
 ('cx', 675),
 ('dt', 663),
 ('ej', 622),
 ('ao', 614),
 ('iz', 609),
 ('cm', 585),
 ('gp', 585),
 ('hr', 582),
 ('cy', 566),
 ('ez', 547),
 ('tx', 545),
 ('gl', 524),
 ('fn', 498),
 ('rw', 491),
 ('ix', 490),
 ('dy', 479),
 ('sv', 443),
 ('cd', 442),
 ('lm', 440),
 ('eq', 430),
 ('dg', 420),
 ('bt', 389),
 ('bs', 384),
 ('iy', 378),
 ('oz', 359),
 ('dp', 352),
 ('dm', 341),
 ('ij', 341),
 ('bn', 336),
 ('fs', 336),
 ('bc', 328),
 ('dv', 325),
 ('hy', 287),
 ('ox', 260),
 ('fy', 254),
 ('mn', 252),
 ('km', 251),
 ('df', 248),
 ('cp', 244),
 ('nz', 225),
 ('bd', 218),
 ('aq', 217),
 ('dw', 215),
 ('uz', 210),
 ('ku', 207),
 ('hl', 199),
 ('jn', 195),
 ('ky', 191),
 ('gm', 183),
 ('hm', 179),
 ('lw', 178),
 ('np', 177),
 ('cf', 176),
 ('kw', 176),
 ('dh', 165),
 ('kt', 164),
 ('cv', 153),
 ('wy', 150),
 ('bp', 142),
 ('tv', 140),
 ('cq', 139),
 ('vy', 139),
 ('sx', 131),
 ('lv', 125),
 ('qs', 118),
 ('pv', 112),
 ('dx', 100),
 ('tz', 100),
 ('hk', 99),
 ('js', 98),
 ('bv', 95),
 ('fp', 95),
 ('cg', 93),
 ('jt', 93),
 ('bg', 91),
 ('lx', 89),
 ('dk', 87),
 ('gv', 87),
 ('fm', 86),
 ('nx', 85),
 ('fv', 83),
 ('mx', 83),
 ('dj', 82),
 ('kp', 81),
 ('mw', 79),
 ('bh', 77),
 ('gz', 77),
 ('iq', 75),
 ('fh', 72),
 ('uv', 71),
 ('rx', 70),
 ('fw', 69),
 ('pw', 68),
 ('qt', 65),
 ('bj', 62),
 ('lz', 59),
 ('qr', 57),
 ('bf', 56),
 ('bk', 56),
 ('fg', 56),
 ('jr', 55),
 ('gw', 52),
 ('fk', 50),
 ('hx', 50),
 ('rz', 50),
 ('jp', 48),
 ('xy', 48),
 ('yz', 44),
 ('bx', 43),
 ('dq', 39),
 ('lq', 39),
 ('fx', 36),
 ('cw', 35),
 ('oq', 34),
 ('hv', 33),
 ('jm', 33),
 ('jx', 31),
 ('mz', 31),
 ('sz', 30),
 ('bw', 29),
 ('hz', 29),
 ('gx', 27),
 ('dz', 26),
 ('jy', 25),
 ('mv', 24),
 ('nq', 24),
 ('ux', 22),
 ('gj', 21),
 ('hj', 21),
 ('bz', 18),
 ('hq', 18),
 ('kz', 18),
 ('vw', 18),
 ('jv', 17),
 ('cz', 16),
 ('jw', 16),
 ('cj', 15),
 ('uw', 15),
 ('gk', 14),
 ('jl', 13),
 ('fj', 11),
 ('qy', 11),
 ('vx', 11),
 ('kv', 8),
 ('kx', 8),
 ('pz', 8),
 ('qw', 7),
 ('fq', 5),
 ('pq', 5),
 ('bq', 4),
 ('mq', 4),
 ('vz', 4),
 ('jk', 3),
 ('jz', 3),
 ('fz', 2),
 ('qz', 2),
 ('wz', 2),
 ('gq', 1),
 ('jq', 1),
 ('qx', 1),
 ('wx', 1),
 ('xz', 1),
 ('kq', 0),
 ('qv', 0)]
alpha_List = [chr(i) for i in range(ord('a'),ord('z')+1)]
alpha_List.index('a')

weights = [x[1] for x in f_count]
edges = []
for x in f_count:
    edges.append((alpha_List.index(x[0][0]),alpha_List.index(x[0][1])))
edges = [(i, j, w) for (i, j),w in zip(edges, weights)]

from collections import defaultdict
adj_list = defaultdict(list)
for src, tar, w in edges:
    adj_list[src].append((tar, w))
    adj_list[tar].append((src, w))

for i in range(len(adj_list)):
    adj_list[i] = sorted(adj_list[i])

# %%
from typing import Dict, List, Tuple
from math import floor
def adj_list_to_edgelist(adj_list : Dict[str, List[Tuple[str, int]]]) -> List[Tuple[str, str, int]]:
    L = []
    for src, edges in adj_list.items():
        for tar, w in edges:
            L.append((src, tar, w))
    return L




def SDP_solver(matrix_size,edge_tuple):
    X = cp.Variable((matrix_size,matrix_size),symmetric = True)
    constraints = [X>>0]
    constraints +=[
        X[i,i] == 1
        for i in range(matrix_size)
    ]
    constraints += [
        cp.sum(cp.sum(X)) <= 0
    ]
        
    objective  = sum((1/2)*w*(1-X[i,j]) for (i,j,w) in edge_tuple)
    #objective  = sum((1/2)*w*(1-X[i,j]) for (i,j,w) in edges)
    prob = cp.Problem(cp.Maximize(objective),constraints)
    prob.solve()
    x = sqrtm(X.value)
    return x

# step 2
def step_two(x):
    u = np.random.randn(len(x),2)
    x = x@u
    letter_index = np.argmax(x, axis=1)
    return(letter_index)

#decide the index for St group
def step_three(letter_index):
    num = sum(letter_index)
    if sum(letter_index) > len(letter_index)/2:
        GroupA, GroupB = 1, 0
    else:
        GroupA, GroupB = 0, 1
    zeta_index = np.where(letter_index == GroupA)[0]
    return(zeta_index)

#calculate zeta score for each vi node in St groups and return a sorted list
def step_four(zeta_index,adj_list,n_in_group):
    zeta_value = []
    zeta_index_set = set(zeta_index)
    for index in zeta_index:
        zeta = 0
        for tar, w in adj_list[index]:
                if tar not in zeta_index_set:
                    zeta += w
        zeta_value.append(int(zeta))  
    ns = np.argsort(np.array(zeta_value))[::-1][:n_in_group].astype(int)
    group = [zeta_index[i] for i in ns]
    return group

def compute_score(St_tilda, adj_list,size):
    alphabet = np.zeros(size)
    #formatting yi*yj list
    alphabet[St_tilda] = 1
    alphabet[alphabet == 0] = -1
    #COMPUTING SIGMA w_ij(1-yi*yj) for i<j
    sum_n = 0
    for i in range(size):
        for j in range(i):
            sum_n += adj_list[i][j][1]*(1-alphabet[j]*alphabet[i])
    return(sum_n)
###check this function
# def remove_lower_v(max_score,d):
#     for key,value in d.items():
#         if value[0] < max_score:
#             d.pop(key)
#             print(d)
        
#     return d

def create_subset(List,adj_list):
    copy_adj_list = copy.deepcopy(adj_list)
    adj_list_sub = []
    adj_list_sub = dict((k, copy_adj_list[k]) for k in List if k in copy_adj_list)
    adj_list_sub_copy = copy.deepcopy(adj_list_sub)
    for node in List:
        for edge in adj_list_sub_copy[node]:
            if edge[0] not in List:
                #print(adj_list_sub[node])
                adj_list_sub[node].remove(edge)
                #print(adj_list_sub[node])
    return adj_list_sub

def reindex_edgelist(edgelist, node_list):
    edgelist_reindex = []
    for item in edgelist:
        edgelist_reindex.append((node_list.index(item[0]),node_list.index(item[1]),item[2]))
    return edgelist_reindex

def repeat_steps(x,L,adj_list,iteration_n):
    max_score = 0
    Dic_counting = {}
    for k in range(iteration_n):
        letter_index = step_two(x)
        zeta_index = step_three(letter_index)
        zeta_index = [L[index] for index in zeta_index]
        St_tilda = step_four(zeta_index,adj_list,floor(len(letter_index)/2))
        #here notice the size of len(adj_list)
        score = compute_score(St_tilda, adj_list,len(adj_list))
        if score >= max_score:
            max_score = score
            if tuple(St_tilda) in Dic_counting:
                Dic_counting[tuple(St_tilda)][1] = Dic_counting[tuple(St_tilda)][1]+1
            else:
                Dic_counting.update({tuple(St_tilda):[score, 1]})
        #Dic_counting_21 = remove_lower_v(max_score_21,Dic_counting_21)
    return Dic_counting

# %%
edge_tuple = adj_list_to_edgelist(adj_list)
x = SDP_solver(26,edge_tuple)
# Out:
# /Users/selenahu/opt/miniconda3/envs/diamonds2022/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
Dic_counting = repeat_steps(x,list(range(26)),adj_list,100)
print(Dic_counting)
# Out:
# {(17, 0, 8, 18, 13, 14, 7, 11, 20, 12, 24, 23, 5): [1178298.0, 1], (4, 0, 14, 8, 20, 7, 6, 24, 10, 23, 9, 25, 16): [1668732.0, 25], (13, 17, 19, 18, 11, 2, 3, 12, 15, 5, 1, 21, 22): [1668732.0, 26]}

# %%
L_21 = [13, 17, 19, 18, 11,  2  ,3 ,12, 15,  5 , 1, 21 ,22]
L_22 = [ 4,  0, 14,  8, 20,  7,  6, 24, 10, 23,  9, 25, 16]

#select subset from the larger adj_list
adj_list_l21 =  create_subset(L_21,adj_list)  
adj_list_l22 =  create_subset(L_22,adj_list) 
#print(adj_list_l21)

# change the sub_adj_list to sub_edge_List
edgelist_l21 = adj_list_to_edgelist(adj_list_l21) 
#print(edgelist_l21)
edgelist_l22 = adj_list_to_edgelist(adj_list_l22) 

#reindex the sub_edge_List within the length range of the 
#list so that we can use their index later to set the matrix
reindex_edgel_21 = reindex_edgelist(edgelist_l21, L_21)
reindex_edgel_22 = reindex_edgelist(edgelist_l22, L_22)

# %%
x21 = SDP_solver(13,reindex_edgel_21)

# %%
x22 = SDP_solver(13,reindex_edgel_22)

# %%
#first two groups
L_41 = repeat_steps(x21,L_21,adj_list,100)
L_41 = list(max(L_41, key = L_41.get))
L_42 = [x for x in L_21 if x not in L_41]

#second groups
L_43 = repeat_steps(x22,L_22,adj_list,100)
L_43 = list(max(L_43, key = L_43.get))
L_44 = [x for x in L_22 if x not in L_43]

print(f'the four groups by index are:\n{L_41},\n{L_42},\n{L_43},\n{L_44}')
A_41 = [chr(97+i) for i in L_41]
A_42 = [chr(97+i) for i in L_42]
A_43 = [chr(97+i) for i in L_43]
A_44 = [chr(97+i) for i in L_44]
print(f'\nthe four groups by alphabet are:\n{A_41},\n{A_42},\n{A_43},\n{A_44}')
# Out:
# the four groups by index are:
# [13, 17, 18, 11, 12, 5],
# [19, 2, 3, 15, 1, 21, 22],
# [4, 0, 14, 8, 24, 16],
# [20, 7, 6, 10, 23, 9, 25]
#
# the four groups by alphabet are:
# ['n', 'r', 's', 'l', 'm', 'f'],
# ['t', 'c', 'd', 'p', 'b', 'v', 'w'],
# ['e', 'a', 'o', 'i', 'y', 'q'],
# ['u', 'h', 'g', 'k', 'x', 'j', 'z']
